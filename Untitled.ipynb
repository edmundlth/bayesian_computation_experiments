# %%
using Plots

# %%
begin
    K(a, b) = a^2 * b^2 #(a^3 - b^2)^2
    f(x, y, n=10) = exp(-n * K(x, y))
end
# Out:
# f (generic function with 2 methods)

# %%
ϵ = 0.01
x = 0:ϵ:1
y = 0:ϵ:1
p1 = plot(x, y, f, st=:surface, camera=(45, 70))
#p2 = plot(x, y, f, st=:contour)
#plot(p1, p2)
